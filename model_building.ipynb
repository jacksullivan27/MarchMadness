# %%
import data_processing as dp
import warnings
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.metrics import brier_score_loss

# %%
# Create an instance of DataProcessing
data_processor = dp.DataProcessing()

# First, process the KenPom data to create self.kenpom_processed
data_processor.process_kenpom()

# Then, process the tournament data to create self.tourney_processed
data_processor.process_tourney()

# Now you can call get_data()
matchup_stats = data_processor.get_data()
warnings.filterwarnings("ignore")
matchup_stats.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WTeamName  WSeed  \
# 0    2002     134     1373      81     1108      77     Siena     16
# 1    2002     136     1104      86     1194      78   Alabama      2
# 2    2002     136     1112      86     1364      81   Arizona      3
# 3    2002     136     1181      84     1457      37      Duke      1
# 4    2002     136     1231      75     1428      56   Indiana      5
#
#     WRecord         LTeamName  ...  Adjusted Temo_diff  Raw Tempo_diff  \
# 0  0.470588        Alcorn St.  ...                 6.5             6.9
# 1  0.787879  Florida Atlantic  ...                -2.2            -1.5
# 2  0.709677  UC Santa Barbara  ...                 7.7            10.1
# 3  0.906250          Winthrop  ...                 8.6             8.6
# 4  0.633333              Utah  ...                 3.5             3.4
#
#   Adjusted Offensive Efficiency_diff  Raw Offensive Efficiency_diff  \
# 0                               -0.7                            4.6
# 1                               14.4                            7.7
# 2                               11.1                            5.3
# 3                               23.7                           17.0
# 4                                2.6                           -1.3
#
#    Adjusted Defensive Efficiency_diff  Raw Defensive Efficiency_diff  \
# 0                                 6.8                            2.9
# 1                                -6.8                           -3.1
# 2                                -0.5                            7.9
# 3                               -15.8                           -6.0
# 4                                -8.1                           -3.3
#
#    higher_seed_num  lower_seed_num  higher_record  lower_record
# 0               16              16       0.689655      0.470588
# 1                2              15       0.787879      0.642857
# 2                3              14       0.709677      0.655172
# 3                1              16       0.906250      0.576923
# 4                5              12       0.633333      0.703704
#
# [5 rows x 55 columns]

# %%
matchup_stats.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore',
#        'WTeamName', 'WSeed', 'WRecord', 'LTeamName', 'LSeed', 'LRecord',
#        'HigherSeed', 'HigherSeedWin', 'Tempo_diff', 'AdjTempo_diff', 'OE_diff',
#        'AdjOE_diff', 'DE_diff', 'AdjDE_diff', 'AdjEM_diff', 'OffFT_diff',
#        'Off2PtFG_diff', 'Off3PtFG_diff', 'DefFT_diff', 'Def2PtFG_diff',
#        'Def3PtFG_diff', 'eFGPct_diff', 'TOPct_diff', 'ORPct_diff',
#        'FTRate_diff', 'FG2Pct_diff', 'FG3Pct_diff', 'FTPct_diff',
#        'BlockPct_diff', 'OppFG2Pct_diff', 'OppFG3Pct_diff', 'OppFTPct_diff',
#        'OppBlockPct_diff', 'FG3Rate_diff', 'OppFG3Rate_diff', 'ARate_diff',
#        'OppARate_diff', 'StlRate_diff', 'OppStlRate_diff',
#        'Adjusted Temo_diff', 'Raw Tempo_diff',
#        'Adjusted Offensive Efficiency_diff', 'Raw Offensive Efficiency_diff',
#        'Adjusted Defensive Efficiency_diff', 'Raw Defensive Efficiency_diff',
#        'higher_seed_num', 'lower_seed_num', 'higher_record', 'lower_record'],
#       dtype='object')

# %%
# Create a list of the columns we want to use for training
features = [ 'higher_record',  'lower_record', 'Tempo_diff', 'AdjTempo_diff', 'OE_diff',
       'AdjOE_diff', 'DE_diff', 'AdjDE_diff', 'AdjEM_diff', 'OffFT_diff',
       'Off2PtFG_diff', 'Off3PtFG_diff', 'DefFT_diff', 'Def2PtFG_diff',
       'Def3PtFG_diff', 'eFGPct_diff', 'TOPct_diff', 'ORPct_diff',
       'FTRate_diff', 'FG2Pct_diff', 'FG3Pct_diff', 'FTPct_diff',
       'BlockPct_diff', 'OppFG2Pct_diff', 'OppFG3Pct_diff', 'OppFTPct_diff',
       'OppBlockPct_diff', 'FG3Rate_diff', 'OppFG3Rate_diff', 'ARate_diff',
       'OppARate_diff', 'StlRate_diff', 'OppStlRate_diff',
       'Adjusted Temo_diff', 'Raw Tempo_diff',
       'Adjusted Offensive Efficiency_diff', 'Raw Offensive Efficiency_diff',
       'Adjusted Defensive Efficiency_diff', 'Raw Defensive Efficiency_diff']
#'higher_seed_num', 'lower_seed_num',
x_train = matchup_stats[(matchup_stats["Season"] != 2023) & (matchup_stats["Season"] != 2024)][features]
y_train = matchup_stats[(matchup_stats["Season"] != 2023) & (matchup_stats["Season"] != 2024)]['HigherSeedWin'] 

x_validate = matchup_stats[matchup_stats["Season"] == 2023][features]
y_validate = matchup_stats[matchup_stats["Season"] == 2023]['HigherSeedWin']

x_test = matchup_stats[matchup_stats["Season"] == 2024][features]
y_test = matchup_stats[matchup_stats["Season"] == 2024]['HigherSeedWin']

y_test.sum()/y_test.count()
# Out:
# 0.6865671641791045

# %%
x_test
# Out:
#       higher_record  lower_record  Tempo_diff  AdjTempo_diff  OE_diff  \
# 1379       0.696970      0.687500     -5.0894        -5.9624  -8.8920
# 1380       0.500000      0.482759      6.3143         6.2529   8.5507
# 1381       0.705882      0.666667      2.6535         0.9761   3.2860
# 1382       0.548387      0.483871     -3.0147        -4.1201  -7.4340
# 1383       0.757576      0.575758      1.2967         0.7391  11.3010
# 1384       0.718750      0.687500      0.9069         0.7975   8.8910
# 1385       0.774194      0.781250     -2.1790        -2.2919   1.5820
# 1386       0.696970      0.676471      3.2227         2.9560  11.6760
# 1387       0.774194      0.896552      2.4897         2.9828   3.3960
# 1388       0.764706      0.733333      4.4361         5.5125   7.7940
# 1389       0.794118      0.612903     -0.1509        -0.7559   0.8030
# 1390       0.677419      0.843750     -4.0995        -3.6794  -6.5300
# 1391       0.617647      0.575758      2.3129         1.7404  -1.8880
# 1392       0.696970      0.611111     -1.3408        -1.2272   2.5860
# 1393       0.794118      0.482759      8.5851         9.0903  16.6977
# 1394       0.718750      0.676471      5.9091         6.1942   8.2610
# 1395       0.787879      0.676471     -3.5254        -4.0824   0.9960
# 1396       0.750000      0.580645      5.0183         5.2147  13.4763
# 1397       0.625000      0.687500      1.9007         1.3404  -0.4800
# 1398       0.727273      0.818182     -2.1485        -3.1977  -3.7070
# 1399                            6.9                                -3.4
# 1400                           11.2                                -2.8
# 1401                            1.6                                 1.7
# 1402                            1.5                                 2.5
# 1403                           12.7                               -23.2
# 1404                           10.7                                -4.7
# 1405                            2.5                                -3.1
# 1406                            7.2                               -17.5
# 1407                           -1.7                                -1.4
# 1408                            7.4                                -7.3
# 1409                            5.3                                 2.6
# 1410                           21.6                               -12.6
# 1411                           -2.4                               -13.2
# 1412                           -0.6                                -1.8
# 1413                            2.5                                 2.4
# 1414                            7.5                                -9.4
# 1415                            2.7                                -6.7
# 1416                            6.7                                -3.8
# 1417                          -12.7                                -3.8
# 1418                           13.6                                 3.0
# 1419                            0.7                                -9.4
# 1420                           -1.7                                -7.2
# 1421                            5.2                                -0.2
# 1422                            2.0                                -7.5
# 1423                            9.7                                 4.9
# 1424                            4.2                                 2.2
# 1425                           11.9                                -8.4
# 1426                            3.4                                -5.4
# 1427                            1.9                               -12.8
# 1428                           -1.7                                -4.1
# 1429                            7.0                                -6.5
# 1430                           -1.3                                -7.8
# 1431                           -6.9                                -9.5
# 1432                            3.4                                -4.6
# 1433                           14.6                                -2.9
# 1434                           -7.7                               -13.5
# 1435                           -3.9                                -7.5
# 1436                            2.9                                -3.2
# 1437                           -0.8                                -4.8
# 1438                           -4.1                                -6.5
# 1439                            8.1                                 4.7
# 1440                            4.7                                -9.9
# 1441                            8.4                                -3.2
# 1442                            7.1                                 4.4
# 1443                            1.6                               -11.9
# 1444                           10.3                                -3.8
# 1445                            3.7                                -3.5
#
#       Raw Defensive Efficiency_diff
# 1379                           -5.1
# 1380                            6.5
# 1381                            1.9
# 1382                           -2.3
# 1383                           -8.4
# 1384                            0.6
# 1385                            2.1
# 1386                           -0.9
# 1387                            3.5
# 1388                            3.4
# 1389                          -14.1
# 1390                           -0.8
# 1391                            0.9
# 1392                           -0.4
# 1393                           -2.4
# 1394                            0.4
# 1395                           -1.1
# 1396                           -1.7
# 1397                           -0.9
# 1398                           -0.6
# 1399                            4.0
# 1400                            6.0
# 1401                            5.8
# 1402                            3.7
# 1403                          -16.9
# 1404                            1.1
# 1405                           -1.9
# 1406                          -13.6
# 1407                            7.1
# 1408                            1.5
# 1409                           -0.6
# 1410                           -3.6
# 1411                          -10.0
# 1412                           -4.1
# 1413                            2.7
# 1414                           -6.9
# 1415                           -5.4
# 1416                           -3.7
# 1417                            0.1
# 1418                            3.1
# 1419                           -9.1
# 1420                           -2.5
# 1421                           -1.0
# 1422                           -4.9
# 1423                           13.2
# 1424                            0.0
# 1425                           -8.1
# 1426                            1.1
# 1427                          -16.3
# 1428                           -2.1
# 1429                           -2.8
# 1430                           -4.2
# 1431                          -10.5
# 1432                           -7.5
# 1433                           -2.6
# 1434                          -13.5
# 1435                           -9.6
# 1436                           -2.9
# 1437                           -0.2
# 1438                           -5.1
# 1439                            4.7
# 1440                           -7.7
# 1441                           -4.9
# 1442                            4.5
# 1443                          -12.6
# 1444                           -3.2
# 1445                           -3.9
#
# [67 rows x 39 columns]

# %%
# Train the Random Forest model
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)

# Evaluate the model
accuracy_before = rf.score(x_validate, y_validate)
print(f'Accuracy before feature selection: {accuracy_before:.2f}')

importances = rf.feature_importances_
feature_names = x_train.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# Rank features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
feature_importance_df
# Out:
# Accuracy before feature selection: 0.73
#                                Feature  Importance
# 8                           AdjEM_diff    0.125040
# 37  Adjusted Defensive Efficiency_diff    0.050880
# 7                           AdjDE_diff    0.049591
# 35  Adjusted Offensive Efficiency_diff    0.048188
# 5                           AdjOE_diff    0.043116
# 4                              OE_diff    0.028641
# 38       Raw Defensive Efficiency_diff    0.028347
# 29                          ARate_diff    0.026540
# 6                              DE_diff    0.025924
# 36       Raw Offensive Efficiency_diff    0.024549
# 22                       BlockPct_diff    0.024042
# 24                      OppFG3Pct_diff    0.023970
# 31                        StlRate_diff    0.022976
# 21                          FTPct_diff    0.022034
# 19                         FG2Pct_diff    0.020961
# 23                      OppFG2Pct_diff    0.020349
# 0                        higher_record    0.020326
# 30                       OppARate_diff    0.020185
# 32                     OppStlRate_diff    0.020156
# 17                          ORPct_diff    0.020055
# 10                       Off2PtFG_diff    0.019998
# 12                          DefFT_diff    0.019957
# 15                         eFGPct_diff    0.019463
# 16                          TOPct_diff    0.019437
# 26                    OppBlockPct_diff    0.018768
# 20                         FG3Pct_diff    0.018552
# 2                           Tempo_diff    0.018069
# 25                       OppFTPct_diff    0.017934
# 18                         FTRate_diff    0.017806
# 9                           OffFT_diff    0.017738
# 14                       Def3PtFG_diff    0.017540
# 28                     OppFG3Rate_diff    0.017087
# 1                         lower_record    0.017026
# 13                       Def2PtFG_diff    0.016560
# 34                      Raw Tempo_diff    0.016554
# 3                        AdjTempo_diff    0.016400
# 11                       Off3PtFG_diff    0.015757
# 33                  Adjusted Temo_diff    0.014746
# 27                        FG3Rate_diff    0.014738

# %%
# xgb = XGBClassifier(booster = 'gbtree', objective = 'binary:logistic', device = 'gpu', nthread = -1)

# param_grid = {
#     'eta': [0, 1],
#     'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10],  
#     'gamma': [0, 1, 2, 3, 4, 5],
#     'min_child_weight': [1, 2, 3, 4, 5],
#     'max_delta_step': [0, 1, 2, 3, 4, 5],
#     'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1],
#     'lambda': [0, 1, 2, 3, 4, 5],
#     'alpha': [0, 1, 2, 3, 4, 5],
# }

# xgb_random = RandomizedSearchCV(estimator = xgb, param_distributions = param_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# xgb_random.fit(x_train, y_train)
# xgb_random.best_params_

# %%
# {'subsample': 1,
#  'min_child_weight': 3,
#  'max_depth': 10,
#  'max_delta_step': 0,
#  'lambda': 2,
#  'gamma': 5,
#  'eta': 1,
#  'alpha': 3}

# %%
model = XGBClassifier(booster = 'gbtree', objective = 'binary:logistic', device = 'gpu', nthread = -1, subsample = 1, 
                      min_child_weight = 4, max_depth = 7, max_delta_step = 3, reg_lambda = 5, gamma = 4, eta = 1, alpha = 4)

model.fit(x_train, y_train)

importances = model.feature_importances_
feature_names = x_train.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# Rank features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
# feature_importance_df

# %%
print(model.score(x_test, y_test))
preds = model.predict_proba(x_test)[:,1]

outcomes = pd.DataFrame({'Actual': y_test, 'Predicted': preds})
outcomes.head()
# Out:
# 0.8208955223880597
#       Actual  Predicted
# 1379       0   0.155404
# 1380       0   0.391282
# 1381       1   0.238156
# 1382       1   0.156921
# 1383       1   0.955802

# %%
tourney24 = matchup_stats[matchup_stats["Season"] == 2024]
tourney24['Predicted'] = preds
tourney24 = tourney24[['HigherSeed','WTeamName', 'LTeamName', 'WSeed','LSeed', 'HigherSeedWin', 'Predicted']]

# %%
pd.set_option('display.max_rows', None)
display(tourney24)
brier_score_loss(y_test, preds)
# Out:
#             HigherSeed       WTeamName         LTeamName  WSeed  LSeed  \
# 1379          Virginia    Colorado St.          Virginia     10     10
# 1380            Howard          Wagner            Howard     16     16
# 1381          Colorado        Colorado         Boise St.     10     10
# 1382     Grambling St.   Grambling St.       Montana St.     16     16
# 1383           Arizona         Arizona    Long Beach St.      2     15
# 1384         Creighton       Creighton             Akron      3     14
# 1385            Dayton          Dayton            Nevada      7     10
# 1386               BYU        Duquesne               BYU     11      6
# 1387           Gonzaga         Gonzaga       McNeese St.      5     12
# 1388          Illinois        Illinois      Morehead St.      3     14
# 1389          Iowa St.        Iowa St.  South Dakota St.      2     15
# 1390            Kansas          Kansas           Samford      4     13
# 1391   Mississippi St.    Michigan St.   Mississippi St.      9      8
# 1392        Texas Tech        NC State        Texas Tech     11      6
# 1393    North Carolina  North Carolina            Wagner      1     16
# 1394          Kentucky         Oakland          Kentucky     14      3
# 1395    South Carolina          Oregon    South Carolina     11      6
# 1396         Tennessee       Tennessee     Saint Peter's      2     15
# 1397             Texas           Texas      Colorado St.      7     10
# 1398    Washington St.  Washington St.             Drake      7     10
# 1399           Alabama         Alabama        Charleston      4     13
# 1400            Baylor          Baylor           Colgate      3     14
# 1401           Clemson         Clemson        New Mexico      6     11
# 1402           Florida        Colorado           Florida     10      7
# 1403       Connecticut     Connecticut           Stetson      1     16
# 1404              Duke            Duke           Vermont      4     13
# 1405      Saint Mary's    Grand Canyon      Saint Mary's     12      5
# 1406           Houston         Houston          Longwood      1     16
# 1407         Wisconsin   James Madison         Wisconsin     12      5
# 1408         Marquette       Marquette  Western Kentucky      2     15
# 1409  Florida Atlantic    Northwestern  Florida Atlantic      9      8
# 1410            Purdue          Purdue     Grambling St.      1     16
# 1411     San Diego St.   San Diego St.               UAB      5     12
# 1412          Nebraska       Texas A&M          Nebraska      9      8
# 1413          Utah St.        Utah St.               TCU      8      9
# 1414            Auburn            Yale            Auburn     13      4
# 1415           Arizona         Arizona            Dayton      2      7
# 1416         Creighton       Creighton            Oregon      3     11
# 1417            Kansas         Gonzaga            Kansas      5      4
# 1418          Illinois        Illinois          Duquesne      3     11
# 1419          Iowa St.        Iowa St.    Washington St.      2      7
